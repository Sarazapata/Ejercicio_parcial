# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randint(0,100, size = 720)
#print(x)
n,m = 120,6
y = x.reshape(n,m)
y_f = x.reshape(n,m, order= "F")

y_transpuesta= y.T
y_transpuestaF = y_f.T

ax1=plt.axes([ 0, 0.5, 0.25,0.35])
ax2=plt.axes([0.33, 0.5, 0.25,0.20])
ax3=plt.axes([0.66, 0.6, 0.15,0.30])
ax4=plt.axes([0, 0, 0.20,0.40])
ax5=plt.axes([0.3, 0, 0.28,0.35])
ax6=plt.axes([0.66, 0, 0.13,0.42])

ma1= y_transpuesta[4,]
ma2= y_transpuesta[3,]
ma3= y_transpuesta[2,]
ma4= y_transpuesta[1,]
ma5= y_transpuesta[0,]
ma6= y_transpuesta[5,]
ax1.plot(ma1, color="violet", label="Frecuencia pac1")
ax1.set_title('Gráfico de Líneas')
ax1.legend(loc='upper left')

ax2.bar(np.arange(len(ma2)), ma2, color="yellow", label="Poblacion")
ax2.set_title('Gráfico de Barras')
ax2.legend(loc='upper left')

ax3.hist(ma3, bins=5, color="green", label="Probabilidad" )
ax3.set_title('Histograma')
ax3.legend(loc='upper left')

ax4.scatter(np.arange(len(ma4)), ma4, color="salmon", label="Tendencias")
ax4.set_title('Gráfico de Dispersión')
ax3.legend(loc='upper left')

ax5.plot(ma5, color="blue", label="Frecuencia pac2")
ax5.set_title('Gráfico de Líneas')
ax5.legend(loc='upper left')


# random_indices = np.random.choice(len(ma5), size=5, replace=False) 
# random_data = ma5[random_indices]
# labels = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
# random_labels = [labels[i] for i in random_indices]
# ax5.pie(random_data, labels=random_labels, autopct='%1.1f%%', startangle=90)
# ax5.axis('equal')
# ax5.set_title('Diagrama de Sectores')

ax6.boxplot(ma5, patch_artist=True, boxprops=dict(facecolor="red"), label="Distribucion")
ax6.set_title('Diagrama de Caja')
ax6.legend(['Datos'])
ax6.legend(loc='upper left')


plt.show()


#print(f"Este es order C{y_transpuesta}")
#print(f"Este es order F{y_transpuestaF}")
